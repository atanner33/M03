# %%
#11.1
from zoo import *
hours()
# Out:
# Open 9-5 daily

# %%
#11.2
import zoo as menagerie
hours()
# Out:
# Open 9-5 daily

# %%
#16.3 - 16.8
import books2
import sqlite3
conn = sqlite3.connect('books.db')
curs = conn.cursor()
curs.execute('''CREATE TABLE books
             (title CHAR,
             author CHAR,
             year INT)''')

#Having trouble reading books2.csv from my directory. not sure of what command to use without completely 
#rewriting it in this code...
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Alex\Desktop\SDEV 220\SDEV220 [GIT SYNCED]\M04-Jupyter.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Alex/Desktop/SDEV%20220/SDEV220%20%5BGIT%20SYNCED%5D/M04-Jupyter.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> #16.3 - 16.8
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alex/Desktop/SDEV%20220/SDEV220%20%5BGIT%20SYNCED%5D/M04-Jupyter.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import books2
#       <a href='vscode-notebook-cell:/c%3A/Users/Alex/Desktop/SDEV%20220/SDEV220%20%5BGIT%20SYNCED%5D/M04-Jupyter.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> import sqlite3
#       <a href='vscode-notebook-cell:/c%3A/Users/Alex/Desktop/SDEV%20220/SDEV220%20%5BGIT%20SYNCED%5D/M04-Jupyter.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> conn = sqlite3.connect('books.db')
#
# ModuleNotFoundError: No module named 'books2'
